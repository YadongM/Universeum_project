# %%
import wandb
wandb.init(project="yolov5_no_aug", entity="yadongm")
# Out:
# Finishing last run (ID:1kkp352e) before initializing another...
# <br/>Waiting for W&B process to finish, PID 20457... <strong style="color:green">(success).</strong>
# ...
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# </div><div class="wandb-col">
# </div></div>
# Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">usual-field-2</strong>: <a href="https://wandb.ai/yadongm/yolov5da2/runs/1kkp352e" target="_blank">https://wandb.ai/yadongm/yolov5da2/runs/1kkp352e</a><br/>
# Find logs at: <code>./wandb/run-20211024_113247-1kkp352e/logs</code><br/>
# Successfully finished last run (ID:1kkp352e). Initializing new run:<br/>
# ...

# %%
## After Data Augmentation

# !CUDA_LAUNCH_BLOCKING=1 python train.py --img 640 --batch 32 --epochs 200 --data ../data/data_no_aug/data.yaml --cfg models/yolov5s.yaml --weights weights/yolov5s.pt
# Out:
# wandb: Currently logged in as: yadongm (use `wandb login --relogin` to force relogin)
# train: weights=weights/yolov5s.pt, cfg=models/yolov5s.yaml, data=../data/data_no_aug/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=200, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 3 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.0-27-gb760ace torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3080, 9984.375MB)
#
# ...

# %%
## After Data Augmentation

# !CUDA_LAUNCH_BLOCKING=1 python train.py --img 640 --batch 32 --epochs 200 --data ../data/data_all_aug1/data.yaml --cfg models/yolov5s.yaml --weights weights/yolov5s.pt
# Out:
# wandb: Currently logged in as: yadongm (use `wandb login --relogin` to force relogin)
# train: weights=weights/yolov5s.pt, cfg=models/yolov5s.yaml, data=../data/data_all_aug1/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=200, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 3 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.0-27-gb760ace torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3080, 9984.375MB)
#
# ...

# %%
## After Data Augmentation

# !CUDA_LAUNCH_BLOCKING=1 python train.py --img 640 --batch 32 --epochs 200 --data ../data/data_all_aug2/data.yaml --cfg models/yolov5s.yaml --weights weights/yolov5s.pt
# Out:
# wandb: Currently logged in as: yadongm (use `wandb login --relogin` to force relogin)
# train: weights=weights/yolov5s.pt, cfg=models/yolov5s.yaml, data=../data/data_all_aug2/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=200, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 3 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.0-27-gb760ace torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3080, 9984.375MB)
#
# ...

# %%
# !python val.py  --data ../data/data_no_aug/data_test.yaml --weights ./runs_no_aug/train/exp7/weights/best.pt --augment
# Out:
# val: data=../data/data_no_aug/data_test.yaml, weights=['./runs_no_aug/train/exp7/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=True, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 v6.0-27-gb760ace torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3080, 9984.375MB)
#
# Fusing layers...
# Model Summary: 213 layers, 7066762 parameters, 0 gradients, 16.0 GFLOPs
# val: Scanning '../data/data_no_aug/test/labels.cache' images and labels... 112 f
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        112        144      0.987      0.972      0.989      0.754
#       Amphiprioninae        112          6      0.999          1      0.995      0.735
#             Arapaima        112          9      0.966          1      0.995      0.787
# ...

# %%
# !python val.py  --data ../data/data_all_aug1/data_test.yaml --weights ./runs/train/exp/weights/best.pt --augment
# Out:
# val: data=../data/data_all_aug1/data_test.yaml, weights=['./runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=True, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 v6.0-27-gb760ace torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3080, 9984.375MB)
#
# Fusing layers...
# Model Summary: 213 layers, 7066762 parameters, 0 gradients, 16.0 GFLOPs
# val: Scanning '../data/data_all_aug1/test/labels.cache' images and labels... 112
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        112        144      0.923      0.959      0.985      0.696
#       Amphiprioninae        112          6      0.977          1      0.995      0.744
#             Arapaima        112          9      0.894      0.945      0.984       0.72
# ...

# %%
# !python val.py  --data ../data/data_all_aug2/data_test.yaml --weights ./runs/train/exp2/weights/best.pt --augment
# Out:
# val: data=../data/data_all_aug2/data_test.yaml, weights=['./runs/train/exp2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, single_cls=False, augment=True, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 v6.0-27-gb760ace torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3080, 9984.375MB)
#
# Fusing layers...
# Model Summary: 213 layers, 7066762 parameters, 0 gradients, 16.0 GFLOPs
# val: Scanning '../data/data_all_aug2/test/labels.cache' images and labels... 112
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        112        144      0.953      0.957      0.975      0.725
#       Amphiprioninae        112          6          1       0.94      0.995      0.677
#             Arapaima        112          9      0.967          1      0.995      0.775
# ...

# %%
# !python detect.py --source ../data/data_no_aug/test/images/ --weights ./runs_no_aug/train/exp7/weights/best.pt --augment
# Out:
# detect: weights=['./runs_no_aug/train/exp7/weights/best.pt'], source=../data/data_no_aug/test/images/, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=True, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-27-gb760ace torch 1.7.1+cu110 CUDA:0 (NVIDIA GeForce RTX 3080, 9984.375MB)
#
# Fusing layers...
# Model Summary: 213 layers, 7066762 parameters, 0 gradients, 16.0 GFLOPs
# image 1/113 /home/jsun/SSY340/Proj/data/data_no_aug/test/images/Amphiprioninae25_jpg.rf.b83fa5a315ff8c4a7f9718a6df7324ff.jpg: 640x640 2 Amphiprioninaes, Done. (0.023s)
# image 2/113 /home/jsun/SSY340/Proj/data/data_no_aug/test/images/Amphiprioninae38_jpg.rf.c5cb8214b9cb391f997d3d49a47fb398.jpg: 640x640 1 Amphiprioninae, Done. (0.021s)
# ...
